# %% [markdown]
# ## 결과 분석

# %%
df_all = pd.read_csv('url_classification_241015.csv')

# %%
# 500개 URL(VT 300개, ATIP 200개)
# columns : url, class, label, origin, classification, report
#   - url : URL 주소
#   - class : Malicious(1), Normal(0)
#   - label : Malicious, Normal
#   - origin : vt_241015(VT 검증, 300개(normal(150)-(150)Malicious)), atip_241015(ATIP 검증, 200개(normal(100)-(100)maliciouns))
#   - classification : Llama3.2 1B URL 분류 결과
#   - report : Llama3.2 1B URL 보고성 생성 결과
print(df_all.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             500 non-null    object
#  1   class           500 non-null    int64
#  2   label           500 non-null    object
#  3   origin          500 non-null    object
#  4   classification  500 non-null    object
#  5   report          500 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 23.6+ KB
# None

# %%
# 접속가능 URL 총 253개
# 정상(215/250)
# 악성 (38/250)
df_clean = df_all[~df_all['classification'].str.startswith('Error-')]
print(df_clean.info())
print(f"\n{df_clean['class'].value_counts()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 1 to 482
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             253 non-null    object
#  1   class           253 non-null    int64
#  2   label           253 non-null    object
#  3   origin          253 non-null    object
#  4   classification  253 non-null    object
#  5   report          253 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 13.8+ KB
# None
#
# class
# 0    215
# 1     38
# Name: count, dtype: int64

# %%
# Vaccine에 의해 차단된 URL 65개
df_dirty = df_all[df_all['classification'].str.contains('호스트에 의해')]
df_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65 entries, 150 to 498
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             65 non-null     object
#  1   class           65 non-null     int64
#  2   label           65 non-null     object
#  3   origin          65 non-null     object
#  4   classification  65 non-null     object
#  5   report          65 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 3.6+ KB

# %%
df_dirty
# Out:
#                                                    url  class      label  \
# 150    https://fwebmail-account-105410.weeblysite.com/      1  Malicious
# 154             https://fkucc2024.lovestoblog.com/?i=1      1  Malicious
# 155             https://fkucc2024.lovestoblog.com/?i=1      1  Malicious
# 158  https://digijudicial.com/includes/000response/...      1  Malicious
# 160      https://buymore.com.ng/slot-zeus/interia.html      1  Malicious
# ..                                                 ...    ...        ...
# 463                      http://alkawalis.com/?p=32358      1  Malicious
# 464  http://archifox936.netlify.app/free-voice-over...      1  Malicious
# 493  https://insearchofmorepodcast.com/atuoejiy.php...      1  Malicious
# 497                               http://www.naver.cm/      1  Malicious
# 498                         http://m-facebookk.com.vn/      1  Malicious
#
#           origin                                     classification  \
# ...
